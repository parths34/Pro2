# %% [markdown]
# ✅ Step 1: Import Libraries & Load Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Correct loading (IMPORTANT)
wsaddata = pd.read_csv('AirQuality.csv', sep=';', decimal=',')

# Remove empty columns
data = data.dropna(axis=1, how='all')

# %% [markdown]
# 📊 1. Box Plot (Outliers Detection)

# %%
plt.figure()
sns.boxplot(data=data['CO(GT)'])  # CO levels
plt.title("Box Plot of CO(GT)")
plt.show()

# %% [markdown]
# 📊 2. Histogram (Frequency Distribution)

# %%
plt.figure()
plt.hist(data['NO2(GT)'], bins=20)
plt.title("Histogram of NO2(GT)")
plt.xlabel("NO2 Levels")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 📈 3. Single Line Graph (Trend)

# %%
plt.figure()
plt.plot(data['CO(GT)'])
plt.title("CO(GT) Trend")
plt.xlabel("Index")
plt.ylabel("CO Levels")
plt.show()

# %%
print(data.dtypes)
# Out:
# Date              object
# Time              object
# CO(GT)           float64
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# dtype: object

# %% [markdown]
# 📈 4. Multiple Line Graph (Comparison)

# %%
plt.figure()
plt.plot(data['CO(GT)'], label='CO')
plt.plot(data['NO2(GT)'], label='NO2')
plt.plot(data['NOx(GT)'], label='NOx')

plt.title("Air Quality Comparison")
plt.xlabel("Index")
plt.ylabel("Values")
plt.legend()
plt.show()
